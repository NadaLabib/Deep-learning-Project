# %%
import cv2

# %%
vidcap = cv2.VideoCapture('Demo Video.mp4')
success,image = vidcap.read()
count = 0
while success: 
    cv2.imwrite("frame%d.jpg" % count, image)
    success,image = vidcap.read()
    print('read a new frame: ',success)
    count += 1
# Out:
# read a new frame:  True
# read a new frame:  True
# read a new frame:  True
# read a new frame:  True
# read a new frame:  True
# read a new frame:  True
# read a new frame:  True
# read a new frame:  True
# read a new frame:  True
# read a new frame:  True
# read a new frame:  True
# read a new frame:  True
# read a new frame:  True
# read a new frame:  True
# read a new frame:  True
# read a new frame:  True
# read a new frame:  True
# read a new frame:  True
# read a new frame:  True
# read a new frame:  True
# read a new frame:  True
# read a new frame:  True
# read a new frame:  True
# read a new frame:  True
# read a new frame:  True
# read a new frame:  True
# read a new frame:  True
# read a new frame:  True
# read a new frame:  True
# read a new frame:  True
# read a new frame:  True
# read a new frame:  True
# read a new frame:  True
# read a new frame:  True
# read a new frame:  True
# read a new frame:  True
# read a new frame:  True
# read a new frame:  True
# ...
